# %%
print("Welcome to Data Science")
# Out:
# Welcome to Data Science

# %%
x = 5
print(x)
print("Value of x is:", x)
print(type(x))
# Out:
# 5
# Value of x is: 5
# <class 'int'>

# %%
y = 3.14
print(y)
print(type(y))
# Out:
# 3.14
# <class 'float'>

# %%
z = "Nazeef Khan"
print(z)
print(type(z))
# Out:
# Nazeef Khan
# <class 'str'>
